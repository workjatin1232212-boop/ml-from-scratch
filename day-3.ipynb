# %%
# Feature: request size (KB)
X = np.array([10, 20, 30, 40, 50])

# Target: response time (ms)
y = np.array([120, 180, 250, 310, 400])

# Convert X to column vector (n, 1)
X = X.reshape(-1, 1)

# Initialize weight
W = 0.0

# Predictions
y_pred = X.flatten() * W

print("Initial predictions:", y_pred)
# Out:
# Initial predictions: [0. 0. 0. 0. 0.]

# %%
y_pred=X*y
y_pred
# Out:
# array([ 1200,  3600,  7500, 12400, 20000])
